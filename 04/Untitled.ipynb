# %%
import pandas as pd

# %% [markdown]
#  - načtení dat z csv souboru

# %%
df_nehody = pd.read_csv ('dopravni_nehody_brno.csv')
# Out:
# /tmp/ipykernel_146472/2384062965.py:1: DtypeWarning: Columns (12,13,21,22,23,24,25,26,27,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nehody = pd.read_csv ('dopravni_nehody_brno.csv')

# %% [markdown]
#  - zobrazení prvních 5-ti záznamů z dataframe

# %%
df_nehody.head()
# Out:
#    OBJECTID            zuj alkohol_vinik          hlavni_pricina  \
# 0         1  Brno-Bosonohy            ne  nesprávný způsob jízdy
# 1         2  Brno-Bosonohy            ne  nesprávný způsob jízdy
# 2         3  Brno-Bosonohy            ne  nesprávný způsob jízdy
# 3         4  Brno-Bosonohy            ne  nesprávný způsob jízdy
# 4         5     Brno-střed            ne  nesprávný způsob jízdy
#
#                                    srazka  \
# 0  srážka s jedoucím nekolejovým vozidlem
# 1  srážka s jedoucím nekolejovým vozidlem
# 2  srážka s jedoucím nekolejovým vozidlem
# 3  srážka s jedoucím nekolejovým vozidlem
# 4  srážka s jedoucím nekolejovým vozidlem
#
#                                   nasledky  \
# 0  nehoda s následky na životě nebo zdraví
# 1  nehoda s následky na životě nebo zdraví
# 2  nehoda s následky na životě nebo zdraví
# 3  nehoda s následky na životě nebo zdraví
# 4  nehoda s následky na životě nebo zdraví
#
#                                        pricina                stav_vozovky  \
# 0  nedodržení bezpečné vzdálenosti za vozidlem  povrch suchý, neznečistěný
# 1  nedodržení bezpečné vzdálenosti za vozidlem  povrch suchý, neznečistěný
# 2  nedodržení bezpečné vzdálenosti za vozidlem  povrch suchý, neznečistěný
# 3  nedodržení bezpečné vzdálenosti za vozidlem  povrch suchý, neznečistěný
# 4       řidič se plně nevěnoval řízení vozidla  povrch suchý, neznečistěný
#
#   povetrnostni_podm rozhled  ... mesic          e         d    id_nehody  \
# 0      jiné ztížené   dobré  ...    10 -1162828.0 -604429.0  60023000061
# 1      jiné ztížené   dobré  ...    10 -1162828.0 -604429.0  60023000061
# 2      jiné ztížené   dobré  ...    10 -1162828.0 -604429.0  60023000061
# 3      jiné ztížené   dobré  ...    10 -1162828.0 -604429.0  60023000061
# 4         neztížené   dobré  ...     1 -1160611.0 -599755.0  60223000001
#
#                     datum hmotna_skoda skoda_vozidlo  \
# 0  10/13/2023 12:00:00 AM       146000         30000
# 1  10/13/2023 12:00:00 AM       146000         30000
# 2  10/13/2023 12:00:00 AM       146000         30000
# 3  10/13/2023 12:00:00 AM       146000         30000
# 4    1/1/2023 12:00:00 AM        32000          2000
#
#                                GlobalID         x          y
# 0  c62eb690-ecc9-4d0d-b849-403c70c60d66 -604429.0 -1162828.0
# 1  c2c5fdc8-598d-4d99-b843-571ad873baaa -604429.0 -1162828.0
# 2  0ed785d7-9fe2-4439-b7bf-761caf5d39bb -604429.0 -1162828.0
# 3  396ab3e3-1b85-4d51-8103-6c7ac2bec807 -604429.0 -1162828.0
# 4  e8500cfe-66c1-4f39-8e67-6657b06d50fb -599755.0 -1160611.0
#
# [5 rows x 69 columns]

# %% [markdown]
#  - zobrazení seznamu sloupců

# %%
print(df_nehody.columns)
# Out:
# Index(['OBJECTID', 'zuj', 'alkohol_vinik', 'hlavni_pricina', 'srazka',
#        'nasledky', 'pricina', 'stav_vozovky', 'povetrnostni_podm', 'rozhled',
#        'misto_nehody', 'druh_komun', 'pneumatiky', 'druh_pohonu',
#        'druh_vozidla', 'mestska_cast', 'pohlavi', 'alkohol', 'den_v_tydnu',
#        'mesic_t', 'katastr', 'chovani_chodce', 'stav_chodce', 'drogy_chodec',
#        'alkohol_chodec', 'osobni_prepravnik', 'reflexni_prvky',
#        'kategorie_chodce', 'nasledek', 'ozn_osoba', 'zavineni', 'viditelnost',
#        'situovani', 'osoba', 'stav_ridic', 'doba', 'smrt_po', 'lz',
#        'TARGET_FID', 'Join_Count', 'OBJECTID.1', 'Join_Count.1',
#        'TARGET_FID.1', 'den', 'vek', 'smrt_dny', 'rok_nar', 'p48a', 'p59d',
#        'rok', 'tz', 'smrt', 'lehce_zran_os', 'tezce_zran_os', 'usmrceno_os',
#        'id_vozidla', 'hodina', 'ovlivneni_ridice', 'cas', 'mesic', 'e', 'd',
#        'id_nehody', 'datum', 'hmotna_skoda', 'skoda_vozidlo', 'GlobalID', 'x',
#        'y'],
#       dtype='object')

# %% [markdown]
#  - informace o sloupcích

# %%
df_nehody.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74099 entries, 0 to 74098
# Data columns (total 69 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OBJECTID           74099 non-null  int64
#  1   zuj                74099 non-null  object
#  2   alkohol_vinik      74099 non-null  object
#  3   hlavni_pricina     74099 non-null  object
#  4   srazka             74099 non-null  object
#  5   nasledky           74099 non-null  object
#  6   pricina            74099 non-null  object
#  7   stav_vozovky       74099 non-null  object
#  8   povetrnostni_podm  74099 non-null  object
#  9   rozhled            74099 non-null  object
#  10  misto_nehody       74036 non-null  object
#  11  druh_komun         74099 non-null  object
#  12  pneumatiky         3108 non-null   object
#  13  druh_pohonu        3539 non-null   object
#  14  druh_vozidla       74099 non-null  object
#  15  mestska_cast       74099 non-null  object
#  16  pohlavi            54719 non-null  object
#  17  alkohol            74099 non-null  object
#  18  den_v_tydnu        74099 non-null  object
#  19  mesic_t            74099 non-null  object
#  20  katastr            74092 non-null  object
#  21  chovani_chodce     3044 non-null   object
#  22  stav_chodce        3044 non-null   object
#  23  drogy_chodec       161 non-null    object
#  24  alkohol_chodec     161 non-null    object
#  25  osobni_prepravnik  160 non-null    object
#  26  reflexni_prvky     160 non-null    object
#  27  kategorie_chodce   3044 non-null   object
#  28  nasledek           54773 non-null  object
#  29  ozn_osoba          54734 non-null  object
#  30  zavineni           74099 non-null  object
#  31  viditelnost        74099 non-null  object
#  32  situovani          74099 non-null  object
#  33  osoba              51696 non-null  object
#  34  stav_ridic         51609 non-null  object
#  35  doba               74099 non-null  object
#  36  smrt_po            30 non-null     float64
#  37  lz                 74099 non-null  int64
#  38  TARGET_FID         74099 non-null  int64
#  39  Join_Count         74099 non-null  int64
#  40  OBJECTID.1         74099 non-null  int64
#  41  Join_Count.1       74099 non-null  int64
#  42  TARGET_FID.1       74099 non-null  int64
#  43  den                74099 non-null  int64
#  44  vek                54628 non-null  float64
#  45  smrt_dny           52283 non-null  float64
#  46  rok_nar            54628 non-null  float64
#  47  p48a               60257 non-null  float64
#  48  p59d               54628 non-null  float64
#  49  rok                74099 non-null  int64
#  50  tz                 74099 non-null  int64
#  51  smrt               74099 non-null  int64
#  52  lehce_zran_os      74099 non-null  int64
#  53  tezce_zran_os      74099 non-null  int64
#  54  usmrceno_os        74099 non-null  int64
#  55  id_vozidla         71055 non-null  float64
#  56  hodina             74098 non-null  float64
#  57  ovlivneni_ridice   51609 non-null  float64
#  58  cas                74099 non-null  int64
#  59  mesic              74099 non-null  int64
#  60  e                  74099 non-null  float64
#  61  d                  74099 non-null  float64
#  62  id_nehody          74099 non-null  int64
#  63  datum              74099 non-null  object
#  64  hmotna_skoda       74099 non-null  int64
#  65  skoda_vozidlo      74099 non-null  int64
#  66  GlobalID           74099 non-null  object
#  67  x                  74099 non-null  float64
#  68  y                  74099 non-null  float64
# dtypes: float64(13), int64(19), object(37)
# memory usage: 39.0+ MB
